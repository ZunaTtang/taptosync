# %%
# for i in range(100):
# 	print('fsdfsdfs')
a=[{'a':'fsd64564564fs'}]*30
import json
{'a':123,'b':a}
# Out:
# {'a': 123,
#  'b': [{'a': 'fsd64564564fs'},
#   {'a': 'fsd64564564fs'},
#   {'a': 'fsd64564564fs'},
#   {'a': 'fsd64564564fs'},
#   {'a': 'fsd64564564fs'},
#   {'a': 'fsd64564564fs'},
#   {'a': 'fsd64564564fs'},
#   {'a': 'fsd64564564fs'},
#   {'a': 'fsd64564564fs'},
#   {'a': 'fsd64564564fs'},
#   {'a': 'fsd64564564fs'},
#   {'a': 'fsd64564564fs'},
#   {'a': 'fsd64564564fs'},
#   {'a': 'fsd64564564fs'},
#   {'a': 'fsd64564564fs'},
#   {'a': 'fsd64564564fs'},
#   {'a': 'fsd64564564fs'},
#   {'a': 'fsd64564564fs'},
#   {'a': 'fsd64564564fs'},
#   {'a': 'fsd64564564fs'},
#   {'a': 'fsd64564564fs'},
#   {'a': 'fsd64564564fs'},
#   {'a': 'fsd64564564fs'},
#   {'a': 'fsd64564564fs'},
#   {'a': 'fsd64564564fs'},
#   {'a': 'fsd64564564fs'},
#   {'a': 'fsd64564564fs'},
#   {'a': 'fsd64564564fs'},
#   {'a': 'fsd64564564fs'},
#   {'a': 'fsd64564564fs'}]}
